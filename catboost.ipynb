# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import HuberRegressor
import xgboost as xgb
from sklearn import tree
from sklearn import svm
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import StratifiedKFold
import time

# %%
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %%
from preprocess import preprocess

X_train, X_test, y_train = preprocess(df_train, df_test, use_ohe=True, use_scaling=True)

# %%
from catboost import CatBoostRegressor

# %%
catboost_pipe = Pipeline([
    ('cat', CatBoostRegressor())
])

catboost_categorical_pipe = Pipeline([
    ('cat', CatBoostRegressor(cat_features=cat_features))
])

# %%
def test_pipeline(X, y, pipeline):
    rskf = StratifiedKFold(n_splits=5, random_state=1)
    rmse_scores = []
    for train_index, test_index in rskf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        pipeline.fit(X_train, y_train)
        rmse_scores.append(np.sqrt(mean_squared_error(y_test, np.round(pipeline.predict(X_test)))))

    print("kfolds rmse: {0}, mean rmse: {1}".format(
        str([str(round(x, 3)) for x in sorted(rmse_scores)]),
        round(np.mean(rmse_scores), 3)
    ))

# %% [markdown]
# ###### Ohe with target scaling

# %%
test_pipeline(X_train, y_train, catboost_pipe)
# Out:
# 0:	learn: 1.3137230	total: 97.7ms	remaining: 1m 37s
# 1:	learn: 1.3007325	total: 185ms	remaining: 1m 32s
# 2:	learn: 1.2882799	total: 269ms	remaining: 1m 29s
# 3:	learn: 1.2765361	total: 395ms	remaining: 1m 38s
# 4:	learn: 1.2650646	total: 479ms	remaining: 1m 35s
# 5:	learn: 1.2543591	total: 523ms	remaining: 1m 26s
# 6:	learn: 1.2441234	total: 563ms	remaining: 1m 19s
# 7:	learn: 1.2343546	total: 618ms	remaining: 1m 16s
# 8:	learn: 1.2248857	total: 669ms	remaining: 1m 13s
# 9:	learn: 1.2161648	total: 707ms	remaining: 1m 9s
# 10:	learn: 1.2077050	total: 754ms	remaining: 1m 7s
# 11:	learn: 1.1996896	total: 805ms	remaining: 1m 6s
# 12:	learn: 1.1920651	total: 855ms	remaining: 1m 4s
# 13:	learn: 1.1850089	total: 903ms	remaining: 1m 3s
# 14:	learn: 1.1778761	total: 956ms	remaining: 1m 2s
# 15:	learn: 1.1711604	total: 1s	remaining: 1m 1s
# 16:	learn: 1.1648934	total: 1.05s	remaining: 1m
# 17:	learn: 1.1587981	total: 1.1s	remaining: 1m
# 18:	learn: 1.1531767	total: 1.15s	remaining: 59.5s
# ...

# %% [markdown]
# ##### Target encoding without scaling

# %%
test_pipeline(X_train_transformed.values, y_train, catboost_pipe)
# Out:
# 0:	learn: 1.3136632	total: 96ms	remaining: 1m 35s
# 1:	learn: 1.3006877	total: 184ms	remaining: 1m 32s
# 2:	learn: 1.2883052	total: 280ms	remaining: 1m 33s
# 3:	learn: 1.2765374	total: 375ms	remaining: 1m 33s
# 4:	learn: 1.2651790	total: 463ms	remaining: 1m 32s
# 5:	learn: 1.2543755	total: 554ms	remaining: 1m 31s
# 6:	learn: 1.2441095	total: 648ms	remaining: 1m 31s
# 7:	learn: 1.2345003	total: 734ms	remaining: 1m 31s
# 8:	learn: 1.2252211	total: 839ms	remaining: 1m 32s
# 9:	learn: 1.2163132	total: 927ms	remaining: 1m 31s
# 10:	learn: 1.2079146	total: 1.02s	remaining: 1m 32s
# 11:	learn: 1.1997735	total: 1.11s	remaining: 1m 31s
# 12:	learn: 1.1921136	total: 1.21s	remaining: 1m 31s
# 13:	learn: 1.1847536	total: 1.3s	remaining: 1m 31s
# 14:	learn: 1.1777190	total: 1.4s	remaining: 1m 31s
# 15:	learn: 1.1711527	total: 1.5s	remaining: 1m 31s
# 16:	learn: 1.1646616	total: 1.61s	remaining: 1m 32s
# 17:	learn: 1.1586861	total: 1.7s	remaining: 1m 32s
# ...

# %%
xgb_pipe.fit(X_train, y_train)
y_pred = xgb_pipe.predict(X_test)

# %%
np.save('catboost_pred.npy', y_pred)

# %%
sample = pd.read_csv('./data/origin/sample_submission_L0aRkDL.csv')

# %%
sample['damage_grade'] = np.round(y_pred)

# %%
sample.head()
# Out:
#    building_id  damage_grade
# 0       680648           3.0
# 1       339540           4.0
# 2       487192           4.0
# 3       571276           3.0
# 4       326396           4.0

# %%
sample.head()
# Out:
#    building_id  damage_grade
# 0       680648           3.0
# 1       339540           4.0
# 2       487192           4.0
# 3       571276           3.0
# 4       326396           4.0

# %%
sample.to_csv("./prediction/catboost.csv", index=False)
